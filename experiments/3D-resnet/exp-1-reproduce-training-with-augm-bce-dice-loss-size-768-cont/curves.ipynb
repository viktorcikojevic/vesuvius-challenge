# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("resnet18_3d_seg.csv")
df
# Out:
#      train_loss  val_loss  fbeta_0.20  fbeta_0.25  fbeta_0.30  fbeta_0.35
# 0      0.730594  0.685625    0.137126    0.137186    0.161602    0.200297  \
# 1      0.721581  0.823123    0.137136    0.137475    0.138499    0.140790
# 2      0.712022  0.909424    0.137661    0.138774    0.141438    0.145812
# 3      0.704988  0.908997    0.137363    0.138962    0.149193    0.165242
# 4      0.688830  0.819913    0.137127    0.137267    0.138955    0.144676
# ..          ...       ...         ...         ...         ...         ...
# 140    0.554837  0.602506    0.218824    0.255811    0.297077    0.319997
# 141    0.554631  0.595561    0.219644    0.254949    0.300101    0.320527
# 142    0.554180  0.596173    0.222351    0.246831    0.286035    0.309708
# 143    0.550326  0.607027    0.225838    0.253963    0.289254    0.304328
# 144    0.553216  0.587266    0.221337    0.261447    0.316698    0.335827
#
#      fbeta_0.40  fbeta_0.45  fbeta_0.50  fbeta_0.55  fbeta_0.60  fbeta_0.65
# 0      0.229774    0.252558    0.279049    0.314034    0.343042    0.342272  \
# 1      0.147262    0.154466    0.165012    0.256543    0.275475    0.292295
# 2      0.150933    0.158606    0.167948    0.182904    0.249409    0.255647
# 3      0.234144    0.238204    0.240655    0.242215    0.243930    0.246011
# 4      0.169891    0.240107    0.242558    0.244867    0.247608    0.251762
# ..          ...         ...         ...         ...         ...         ...
# 140    0.326932    0.329909    0.331453    0.331811    0.333578    0.334586
# 141    0.330373    0.337992    0.343856    0.348269    0.351533    0.354043
# 142    0.320000    0.327130    0.332775    0.337766    0.341703    0.344674
# 143    0.312309    0.319041    0.325454    0.331487    0.338236    0.345148
# 144    0.347185    0.354696    0.360921    0.366175    0.371288    0.376195
#
#      fbeta_0.70  fbeta_0.75  fbeta_0.80  fbeta_0.85  fbeta_0.90  fbeta_0.95
# 0      0.221004    0.026158    0.000541    0.000000    0.000000    0.000000  \
# 1      0.305948    0.314843    0.320848    0.279739    0.090216    0.000021
# 2      0.265817    0.278718    0.295778    0.312660    0.308337    0.053053
# 3      0.248493    0.251945    0.262052    0.278122    0.300404    0.084199
# 4      0.259238    0.267392    0.258681    0.183977    0.017226    0.000000
# ..          ...         ...         ...         ...         ...         ...
# 140    0.331291    0.307722    0.221457    0.099157    0.027844    0.000000
# 141    0.353108    0.324637    0.190967    0.018628    0.000000    0.000000
# 142    0.341178    0.311592    0.168118    0.037263    0.001263    0.000000
# 143    0.342056    0.303003    0.199022    0.094897    0.024112    0.000000
# 144    0.380644    0.368866    0.284472    0.059010    0.000000    0.000000
#
#      epoch
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
# ..     ...
# 140    141
# 141    142
# 142    143
# 143    144
# 144    145
#
# [145 rows x 19 columns]

# %%
plt.plot(df["epoch"], df["train_loss"], label="train_loss")
plt.plot(df["epoch"], df["val_loss"], label="val_loss")
# plot the moving average of the validation loss
# plt.plot(df["epoch"], df["val_loss"].rolling(2).mean(), label="val_loss")

plt.legend()
plt.ylim(0.4, 0.6)
# Out:
# (0.4, 0.6)

# %%
plt.plot(df["epoch"], df["fbeta_0.80"], label="fbeta_0.50")
# plt.plot(df["epoch"], df["fbeta_0.95"].rolling(20).mean(), label="fbeta_0.50")


# set horizontal line at 0.5486
plt.axhline(y=0.5486, color='r', linestyle='-')

plt.legend()
# plt.ylim(0.4, 1)

# %%
# take columns that start with "fbeta_"
df_fbeta = df.filter(regex=("fbeta_.*")).values
df_fbeta = np.max(df_fbeta, axis=1)
print(df_fbeta.shape)
plt.plot(df["epoch"], df_fbeta, label="fbeta_max")

plt.plot(df["epoch"], df["fbeta_0.70"], label="fbeta_0.70")

plt.legend()
# Out:
# (145,)
