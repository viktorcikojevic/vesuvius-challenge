# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("resnet34_3d_seg.csv")
df
# Out:
#     epoch        lr  loss_train  loss_val
# 0       1  0.000001    0.128980  0.116200
# 1       2  0.000034    0.094969  0.087436
# 2       3  0.000068    0.053730  0.039759
# 3       4  0.000101    0.035680  0.031087
# 4       5  0.000134    0.029555  0.027990
# ..    ...       ...         ...       ...
# 58     59  0.001000    0.004111  0.008906
# 59     60  0.001000    0.004191  0.004093
# 60     61  0.001000    0.003884  0.003652
# 61     62  0.001000    0.003927  0.003681
# 62     63  0.001000    0.004019  0.003898
#
# [63 rows x 4 columns]

# %%
plt.plot(df["epoch"], np.sqrt(df["loss_train"]), label="train_loss")
plt.plot(df["epoch"], np.sqrt(df["loss_val"]), label="val_loss")
# plot the moving average of the validation loss
# plt.plot(df["epoch"], df["loss_train"].rolling(2).mean(), label="val_loss")

plt.legend()
# plt.ylim(0.05, 0.3)

# %%
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm

arr = []
for i in tqdm(range(100000)):
    noise_sigma = np.random.uniform(0.0, 0.5)
    x = np.abs(np.random.randn(1)*noise_sigma)
    arr.append(x.item())
    
# put vertical line at x=0.2
plt.axvline(x=0.2, color='r', linestyle='--')
plt.axvline(x=0.28, color='r', linestyle='--')
    
plt.hist(arr, bins=100);
# Out:
# 100%|██████████| 100000/100000 [00:00<00:00, 444715.59it/s]

# %%
np.average(arr), np.std(arr)
# Out:
# (0.19987323293007506, 0.20971488115436807)

# %%
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm

arr = []
for i in tqdm(range(100000)):
    noise_sigma = np.random.uniform(0.0, 0.5)
    x = np.abs(np.random.randn(1)*noise_sigma)
    arr.append(x.item())

arr_2 = []
for i in tqdm(range(100000)):
    noise_sigma = np.random.uniform(0.0, 0.5)
    x = np.abs(np.random.randn(1)*noise_sigma)
    arr_2.append(x.item())
# Out:
# 100%|██████████| 100000/100000 [00:00<00:00, 472468.80it/s]
# 100%|██████████| 100000/100000 [00:00<00:00, 499778.25it/s]

# %%
x = (np.array(arr) - 0)**2


print(np.average(x), np.std(x))
plt.hist(np.abs(x), bins=100);
plt.xlim(0, 1)
# Out:
# 0.08376135547608414 0.17709267739394324
# (0.0, 1.0)

# %%
x = (np.array(arr) - np.array(arr_2))
np.sqrt(np.average(x**2))
# Out:
# 0.29549036306624993
