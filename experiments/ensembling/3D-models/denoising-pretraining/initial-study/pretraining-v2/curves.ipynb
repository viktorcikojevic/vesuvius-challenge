# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("resnet34_3d_seg-round-2.csv")
df
# Out:
#      epoch            lr  loss_train  loss_val  fbeta_0.20  fbeta_0.25
# 0        1  4.000000e-05    0.268802  0.252151    0.137125    0.137125  \
# 1        2  4.654657e-05    0.248565  0.313183    0.137125    0.137125
# 2        3  6.600772e-05    0.248437  0.264873    0.137125    0.137125
# 3        4  9.785260e-05    0.247289  0.263880    0.137125    0.137125
# 4        5  1.412126e-04    0.245883  0.272429    0.137125    0.137125
# ..     ...           ...         ...       ...         ...         ...
# 195    196  1.221970e-06    0.241551  0.240943    0.137125    0.137125
# 196    197  6.892299e-07    0.241543  0.241022    0.137125    0.137125
# 197    198  3.085853e-07    0.241528  0.240979    0.137125    0.137125
# 198    199  8.015212e-08    0.241518  0.241095    0.137125    0.137125
# 199    200  4.000000e-09    0.241554  0.241031    0.137125    0.137125
#
#      fbeta_0.30  fbeta_0.35  fbeta_0.40  fbeta_0.45  ...  fbeta_0.55
# 0      0.137125    0.137127    0.137311    0.140175  ...    0.067743  \
# 1      0.137125    0.137125    0.137126    0.137157  ...    0.140017
# 2      0.137125    0.137126    0.137154    0.138259  ...    0.136984
# 3      0.137125    0.137125    0.137137    0.137471  ...    0.117726
# 4      0.137130    0.137264    0.138518    0.138846  ...    0.046703
# ..          ...         ...         ...         ...  ...         ...
# 195    0.137125    0.137125    0.137146    0.137539  ...    0.045412
# 196    0.137125    0.137125    0.137145    0.137520  ...    0.044847
# 197    0.137125    0.137125    0.137145    0.137528  ...    0.044553
# 198    0.137125    0.137125    0.137145    0.137534  ...    0.044135
# 199    0.137125    0.137125    0.137145    0.137495  ...    0.044586
#
#      fbeta_0.60  fbeta_0.65  fbeta_0.70  fbeta_0.75  fbeta_0.80  fbeta_0.85
# 0      0.003097    0.000014    0.000000         0.0         0.0         0.0  \
# 1      0.089248    0.004858    0.000027         0.0         0.0         0.0
# 2      0.042432    0.001659    0.000012         0.0         0.0         0.0
# 3      0.041690    0.005663    0.000128         0.0         0.0         0.0
# 4      0.011152    0.000779    0.000005         0.0         0.0         0.0
# ..          ...         ...         ...         ...         ...         ...
# 195    0.000154    0.000000    0.000000         0.0         0.0         0.0
# 196    0.000181    0.000000    0.000000         0.0         0.0         0.0
# 197    0.000175    0.000000    0.000000         0.0         0.0         0.0
# 198    0.000206    0.000000    0.000000         0.0         0.0         0.0
# 199    0.000156    0.000000    0.000000         0.0         0.0         0.0
#
#      fbeta_0.90  fbeta_0.95  accuracy
# 0           0.0         0.0  0.566965
# 1           0.0         0.0  0.209401
# 2           0.0         0.0  0.344096
# 3           0.0         0.0  0.333580
# 4           0.0         0.0  0.759036
# ..          ...         ...       ...
# 195         0.0         0.0  0.543601
# 196         0.0         0.0  0.543631
# 197         0.0         0.0  0.543799
# 198         0.0         0.0  0.543878
# 199         0.0         0.0  0.543092
#
# [200 rows x 21 columns]

# %%
plt.plot(df["epoch"], df["loss_train"], label="train_loss")
plt.plot(df["epoch"], df["loss_val"], label="val_loss")
# plot the moving average of the validation loss
# plt.plot(df["epoch"], df["loss_train"].rolling(2).mean(), label="val_loss")

plt.legend()
plt.ylim(0.2, 0.3)
# Out:
# (0.2, 0.3)

# %%
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm

arr = []
for i in tqdm(range(100000)):
    noise_sigma = np.random.uniform(0.0, 0.5)
    x = np.abs(np.random.randn(1)*noise_sigma)
    arr.append(x.item())
    
# put vertical line at x=0.2
plt.axvline(x=0.2, color='r', linestyle='--')
plt.axvline(x=0.28, color='r', linestyle='--')
    
plt.hist(arr, bins=100);
# Out:
# 100%|██████████| 100000/100000 [00:00<00:00, 425687.58it/s]

# %%
np.average(arr), np.std(arr)
# Out:
# (0.19960677663396822, 0.20902747685461373)

# %%
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm

arr = []
for i in tqdm(range(100000)):
    noise_sigma = np.random.uniform(0.0, 0.5)
    x = np.abs(np.random.randn(1)*noise_sigma)
    arr.append(x.item())

arr_2 = []
for i in tqdm(range(100000)):
    noise_sigma = np.random.uniform(0.0, 0.5)
    x = np.abs(np.random.randn(1)*noise_sigma)
    arr_2.append(x.item())
# Out:
# 100%|██████████| 100000/100000 [00:00<00:00, 478819.86it/s]
# 100%|██████████| 100000/100000 [00:00<00:00, 527143.14it/s]

# %%
x = (np.array(arr) - 0)**2


print(np.average(x), np.std(x))
plt.hist(np.abs(x), bins=100);
plt.xlim(0, 1)
# Out:
# 0.08301168156096973 0.17416787836970404
# (0.0, 1.0)

# %%
x = (np.array(arr) - np.array(arr_2))
np.sqrt(np.average(x**2))
# Out:
# 0.2947328933849177
