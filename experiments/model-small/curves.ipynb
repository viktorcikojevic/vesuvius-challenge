# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# Load training_log.csv to a pandas dataframe
df = pd.read_csv('metrics.csv')
df
# Out:
#       step      loss  accuracy  precision  f0point5  val_loss  val_accuracy
# 0        0  1.705070  0.807232   0.295693  0.002805  1.569939      0.841175  \
# 1      128  1.598264  0.833527   0.196874  0.006051  1.524015      0.850033
# 2      256  1.554259  0.843291   0.304077  0.061541  1.548784      0.845298
# 3      384  1.653259  0.818059   0.467268  0.260191  1.519552      0.847289
# 4      512  1.580126  0.784087   0.201639  0.172622  1.520448      0.665408
# ..     ...       ...       ...        ...       ...       ...           ...
# 230  29440  1.494614  0.630076   0.263531  0.299436  1.605079      0.454811
# 231  29568  1.410992  0.656300   0.254391  0.289771  1.601043      0.576400
# 232  29696  1.416580  0.687909   0.265649  0.299057  1.596976      0.542513
# 233  29824  1.424792  0.696193   0.271620  0.303972  1.575238      0.604222
# 234  29952  1.465303  0.680846   0.279363  0.313344  1.554616      0.587799
#
#      val_precision  val_f0point5
# 0         0.000000      0.000000
# 1         0.144319      0.015692
# 2         0.162440      0.008292
# 3         0.152822      0.037962
# 4         0.133471      0.142538
# ..             ...           ...
# 230       0.150543      0.175745
# 231       0.149648      0.170013
# 232       0.150232      0.172532
# 233       0.150175      0.169609
# 234       0.143753      0.163781
#
# [235 rows x 9 columns]

# %%
# Plot loss and val_loss vs epoch
plt.figure(figsize=(10, 6))

plt.plot(df['step'], df['loss'], label='loss')
plt.plot(df['step'], df['val_loss'], label='val_loss')
plt.legend()

# %%
# plot accuracy and val_accuracy vs epoch
plt.figure(figsize=(10, 6))

plt.plot(df['step'], df['accuracy'], label='accuracy')
plt.plot(df['step'], df['val_accuracy'], label='val_accuracy')

# plt.ylim(0.6, 1.1)
# set horizontal line at 1.0
plt.axhline(1.0, color='red', linestyle='--')

plt.legend()

# %%
# plot precision and val_precision vs epoch
plt.figure(figsize=(10, 6))

plt.plot(df['step'], df['precision'], label='precision')
plt.plot(df['step'], df['val_precision'], label='val_precision')

plt.ylim(0, 1.1)
# set horizontal line at 1.0
plt.axhline(1.0, color='red', linestyle='--')

plt.legend()

# %%
# plot f0point5 and val_f0point5 vs epoch
plt.figure(figsize=(10, 6))

plt.plot(df['step'], df['f0point5'], label='f0point5')
plt.plot(df['step'], df['val_f0point5'], label='val_f0point5')

plt.ylim(0, 1.1)

# set horizontal line at 1.0
plt.axhline(1.0, color='red', linestyle='--')

plt.legend()
