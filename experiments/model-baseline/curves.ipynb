# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# Load training_log.csv to a pandas dataframe
df = pd.read_csv('metrics.csv')
df
# Out:
#       step      loss  accuracy  precision  f0point5  val_loss  val_accuracy
# 0        0  1.418927  0.449673   0.099162  0.117614  1.526776      0.851482  \
# 1      128  1.586350  0.466634   0.174033  0.202165  1.527750      0.332503
# 2      256  1.584870  0.560711   0.197387  0.224755  1.551335      0.287422
# 3      384  1.464232  0.664553   0.270808  0.306261  1.555486      0.679659
# 4      512  1.476777  0.662550   0.301639  0.340310  1.535011      0.464494
# ..     ...       ...       ...        ...       ...       ...           ...
# 104  13312  1.404641  0.753210   0.409167  0.449562  1.538248      0.614553
# 105  13440  1.304867  0.792202   0.414049  0.451118  1.561403      0.693545
# 106  13568  1.346083  0.781335   0.417191  0.457085  1.560979      0.644630
# 107  13696  1.348214  0.777688   0.410393  0.450517  1.567673      0.598056
# 108  13824  1.372685  0.780810   0.435244  0.474494  1.660797      0.604540
#
#      val_precision  val_f0point5
# ...

# %%
# Plot loss and val_loss vs epoch
plt.figure(figsize=(10, 6))

plt.plot(df['step'], df['loss'], label='loss')
plt.plot(df['step'], df['val_loss'], label='val_loss')
plt.legend()

# %%
# plot accuracy and val_accuracy vs epoch
plt.figure(figsize=(10, 6))

plt.plot(df['step'], df['accuracy'], label='accuracy')
plt.plot(df['step'], df['val_accuracy'], label='val_accuracy')

# plt.ylim(0.6, 1.1)
# set horizontal line at 1.0
plt.axhline(1.0, color='red', linestyle='--')

plt.legend()

# %%
# plot precision and val_precision vs epoch
plt.figure(figsize=(10, 6))

plt.plot(df['step'], df['precision'], label='precision')
plt.plot(df['step'], df['val_precision'], label='val_precision')

plt.ylim(0, 1.1)
# set horizontal line at 1.0
plt.axhline(1.0, color='red', linestyle='--')

plt.legend()

# %%
# plot f0point5 and val_f0point5 vs epoch
plt.figure(figsize=(10, 6))

plt.plot(df['step'], df['f0point5'], label='f0point5')
plt.plot(df['step'], df['val_f0point5'], label='val_f0point5')

plt.ylim(0, 1.1)

# set horizontal line at 1.0
plt.axhline(1.0, color='red', linestyle='--')

plt.legend()
