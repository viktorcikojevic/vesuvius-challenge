# %%
import numpy as np
import gzip
import struct

def load_emnist(file_path):
    with gzip.open(file_path, 'rb') as f:
        zero, data_type, dims = struct.unpack('>HBB', f.read(4))
        shape = tuple(struct.unpack('>I', f.read(4))[0] for d in range(dims))
        return np.frombuffer(f.read(), dtype=np.uint8).reshape(shape)

# %%
train_images = load_emnist('/home/viktor/Documents/kaggle/vesuvius-challenge/external-datasets/emnist/gzip/emnist-byclass-train-images-idx3-ubyte.gz')
train_labels = load_emnist('/home/viktor/Documents/kaggle/vesuvius-challenge/external-datasets/emnist/gzip/emnist-byclass-train-labels-idx1-ubyte.gz')

# %%
import matplotlib.pyplot as plt

plt.imshow(train_images[0], cmap='gray')

# %%
train_images = load_emnist('/home/viktor/Documents/kaggle/vesuvius-challenge/external-datasets/emnist/gzip//emnist-letters-train-images-idx3-ubyte.gz')
test_images = load_emnist('/home/viktor/Documents/kaggle/vesuvius-challenge/external-datasets/emnist/gzip//emnist-letters-test-images-idx3-ubyte.gz')
train_images.shape, test_images.shape
# Out:
# ((124800, 28, 28), (20800, 28, 28))

# %%
import matplotlib.pyplot as plt

i = np.random.randint(0, len(train_images))
x = np.array(train_images[i])
x = np.swapaxes(x, 0, 1)
# x[x>32] = 255
plt.imshow(x, cmap='gray')
